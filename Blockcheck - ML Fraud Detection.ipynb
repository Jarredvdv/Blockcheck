# %% [markdown]
# # Blockcheck

# %% [markdown]
# ### Data Exploration
# Known ponzi scheme wallets

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df_ponzi = pd.read_csv('BTC_ponzi_dataset.csv')
df_ponzi.head(10)
# Out:
#                   Name                             Address    In Tx   Out Tx  \
# 0  Nanoindustryinv.com  1Ee9ZiZkmygAXUiyeYKRSA3tLe4vNYEAgA   1073.0   4247.0
# 1      GrandAgoFinance  1MzNQ7HV8dQ6XQ52zBGYkCZkkWv2Pd3VG6    491.0    826.0
# 2             Cryptory  1FyedPPk923wRfmVphV1CLt3bVLGxHZXpK  10519.0  12304.0
# 3               Leancy  145SmDToAhtfcBQhNxfeM8hnS6CBeiRukY   6901.0  17805.0
# 4         Minimalism10  1FuypAdeC7mSmYBsQLbG9XV261bnfgWbgB     48.0    198.0
# 5        MiniPonziCoin  1F8ZKpjMDpnpF79mZ1pxZRoNKZgXm4Tf1d   1443.0    186.0
# 6             120cycle  1E5MCTtXn7n2svpZ1bDHZXndY9K7qQeqZP    186.0     98.0
# 7         10PERCENTBTC  1BtcBoSSnqe8mFJCUEyCNmo3EcF8Yzhpnc   7116.0   2961.0
# 8             Ponzi.io   1ponziUjuCVdB167ZmTWH48AURW1vE64q   3438.0   2873.0
# 9            LaxoTrade  1LaxoTrQy51LnB289VmoSAgN6J6UrJbfL9   1849.0   2949.0
#
#         In BTC      Out BTC       In USD      Out USD  Paying     Paid  \
# ...
